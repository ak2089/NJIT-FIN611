# %%
# Machine Learning with Python using Linear Regression and Decison Tree
# Import necessary libraries
import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler

# %%
#data path 
df = pd.read_csv('data_ml.csv', parse_dates=['date'])

# %%
df.head()
# Out:
#    stock_id       date  Advt_12M_Usd  Advt_3M_Usd  Advt_6M_Usd  \
# 0        13 2006-12-31          0.25         0.33         0.27
# 1        13 2007-01-31          0.25         0.32         0.28
# 2        13 2007-02-28          0.26         0.30         0.30
# 3        17 2015-03-31          0.73         0.64         0.70
# 4        17 2015-04-30          0.72         0.62         0.66
#
#    Asset_Turnover  Bb_Yld    Bv  Capex_Ps_Cf  Capex_Sales  ...  Total_Capital  \
# 0            0.22    0.33  0.01         0.13         0.84  ...           0.02
# 1            0.22    0.40  0.01         0.13         0.84  ...           0.02
# 2            0.22    0.15  0.01         0.13         0.84  ...           0.02
# 3            0.40    0.47  0.01         0.70         0.74  ...           0.40
# 4            0.40    0.46  0.01         0.70         0.74  ...           0.40
#
#    Total_Debt  Total_Debt_Capital  Total_Liabilities_Total_Assets  Vol1Y_Usd  \
# ...

# %%
df['date']=pd.to_datetime(df['date'])
df.sort_values(by='date')
# Out:
#         stock_id       date  Advt_12M_Usd  Advt_3M_Usd  Advt_6M_Usd  \
# 141020       191 1998-11-30          0.23         0.15         0.19
# 177501       124 1998-11-30          0.78         0.64         0.71
# 282470       950 1998-11-30          1.00         1.00         1.00
# 148895      1171 1998-11-30          0.86         0.87         0.85
# 67282        514 1998-11-30          0.11         0.09         0.09
# ...          ...        ...           ...          ...          ...
# 22625       1117 2019-03-31          0.05         0.04         0.05
# 92897        378 2019-03-31          0.33         0.38         0.36
# 154238      1040 2019-03-31          0.22         0.24         0.24
# 78994        579 2019-03-31          0.14         0.22         0.18
# 5046         837 2019-03-31          0.05         0.04         0.04
#
#         Asset_Turnover  Bb_Yld    Bv  Capex_Ps_Cf  Capex_Sales  ...  \
# 141020            0.50    0.08  0.50         0.49         0.12  ...
# ...

# %%
#splitting data into two parts for Test and Train to test our model 

split_date = pd.to_datetime('01/01/2015')
df_train = df.loc[df['date'] <= split_date]
df_test = df.loc[df['date'] > split_date]
df_train
# Out:
#         stock_id       date  Advt_12M_Usd  Advt_3M_Usd  Advt_6M_Usd  \
# 0             13 2006-12-31          0.25         0.33         0.27
# 1             13 2007-01-31          0.25         0.32         0.28
# 2             13 2007-02-28          0.26         0.30         0.30
# 30            29 2002-09-30          0.43         0.18         0.28
# 31            29 2002-10-31          0.41         0.18         0.23
# ...          ...        ...           ...          ...          ...
# 283375      1205 2004-05-31          0.97         0.97         0.98
# 283376      1205 2004-07-31          0.97         0.96         0.98
# 283377      1205 2004-08-31          0.97         0.96         0.97
# 283378      1205 2004-09-30          0.97         0.96         0.97
# 283379       292 2000-04-30          0.41         0.63         0.52
#
#         Asset_Turnover  Bb_Yld    Bv  Capex_Ps_Cf  Capex_Sales  ...  \
# 0                 0.22    0.33  0.01         0.13         0.84  ...
# ...

# %%
df_test
# Out:
#         stock_id       date  Advt_12M_Usd  Advt_3M_Usd  Advt_6M_Usd  \
# 3             17 2015-03-31          0.73         0.64         0.70
# 4             17 2015-04-30          0.72         0.62         0.66
# 5             17 2015-05-31          0.71         0.63         0.64
# 6             17 2015-06-30          0.70         0.62         0.63
# 7             17 2015-07-31          0.68         0.56         0.60
# ...          ...        ...           ...          ...          ...
# 283364      1158 2018-09-30          0.99         0.99         0.99
# 283365      1158 2018-10-31          0.99         0.99         0.99
# 283366      1158 2018-11-30          0.99         0.99         0.99
# 283367      1158 2018-12-31          0.99         0.99         0.99
# 283368      1158 2019-01-31          0.99         0.99         0.99
#
#         Asset_Turnover  Bb_Yld    Bv  Capex_Ps_Cf  Capex_Sales  ...    Ta  \
# 3                 0.40    0.47  0.01         0.70         0.74  ...  0.42
# ...

# %%
df_train=df_train.drop(columns=["R3M_Usd","R6M_Usd","R12M_Usd"])
df_test=df_test.drop(columns=["R3M_Usd","R6M_Usd","R12M_Usd"])

# %%
predictors1 = df_train.drop(columns=["date"])
predictors2 = df_test.drop(columns=["date"])

# %%
y_train = predictors1["R1M_Usd"]
y_test = predictors2["R1M_Usd"]
predictors_train= predictors1.drop(columns=["R1M_Usd"])
predictors_test= predictors2.drop(columns=["R1M_Usd"])

# %%
import sklearn.preprocessing as sk
scaler = sk.StandardScaler()
predictors_train = scaler.fit_transform(predictors_train)
predictors_test = scaler.fit_transform(predictors_test)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
lr.fit(predictors_train,y_train)
# Out:
# LinearRegression()

# %%
y_prediction = lr.predict(predictors_test)

# %%
y_prediction2 = lr.predict(predictors_train)

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
#this is the test MSE
mean_squared_error(y_test, y_prediction)
# Out:
# 0.047013524936068384

# %%
#this is the train MSE
mean_squared_error(y_train, y_prediction2)
# Out:
# 0.02751907836364312

# %%
#this is the test r2
r2_score(y_test, y_prediction)
# Out:
# -0.0007165889535609704

# %%
#this is the train r2
r2_score(y_train, y_prediction2)
# Out:
# 0.006455321481107612

# %%
scaler = StandardScaler()
Train = scaler.fit_transform(df_train)
Test = scaler.transform(df_test)

Test
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\ANJULK~1\AppData\Local\Temp/ipykernel_11620/381613799.py in <module>
#       1 scaler = StandardScaler()
# ----> 2 Train = scaler.fit_transform(df_train)
#       3 Test = scaler.transform(df_test)
#       4
#       5 Test
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     697         if y is None:
#     698             # fit method of arity 1 (unsupervised transformation)
# --> 699             return self.fit(X, **fit_params).transform(X)
#     700         else:
#     701             # fit method of arity 2 (supervised transformation)
#
# ~\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py in fit(self, X, y, sample_weight)
#     728         # Reset internal state before fitting
#     729         self._reset()
# ...

# %%
#create decision tree
from sklearn.tree import DecisionTreeRegressor
reg = DecisionTreeRegressor()
reg = reg.fit(predictors_train,y_train)

# %%
y_prediction_tree = reg.predict(predictors_test)

# %%
y_prediction_tree = reg.predict(predictors_train)

# %%
import pydotplus 
from IPython.display import Image
